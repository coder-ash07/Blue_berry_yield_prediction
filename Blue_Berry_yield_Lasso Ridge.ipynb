# %% [markdown]
# # Lasso Ridge regularization

# %% [markdown]
# #### As model is underfitting after feature selection according to VIF. We Will try to evaluate model using Lasso and Ridge Regularization

# %% [markdown]
# # Import Libraries

# %%
## EDA libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats  #Used to Calculate Z-Score


## feature engineering libraries
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.model_selection import train_test_split

## model preparation libraries
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

## model evaluation libraries
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %% [markdown]
# # EDA

# %%
berry_data = pd.read_csv('WildBlueberryPollinationSimulationData.csv')
berry_data.head(20)
# Out:
#     Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0      0       37.5      0.75     0.25     0.25   0.25              86.0
# 1      1       37.5      0.75     0.25     0.25   0.25              86.0
# 2      2       37.5      0.75     0.25     0.25   0.25              94.6
# 3      3       37.5      0.75     0.25     0.25   0.25              94.6
# 4      4       37.5      0.75     0.25     0.25   0.25              86.0
# 5      5       37.5      0.75     0.25     0.25   0.25              86.0
# 6      6       37.5      0.75     0.25     0.25   0.25              94.6
# 7      7       37.5      0.75     0.25     0.25   0.25              94.6
# 8      8       37.5      0.75     0.25     0.25   0.25              77.4
# 9      9       37.5      0.75     0.25     0.25   0.25              77.4
# 10    10       37.5      0.75     0.25     0.25   0.25              69.7
# 11    11       37.5      0.25     0.25     0.25   0.25              86.0
# 12    12       37.5      0.25     0.25     0.25   0.25              86.0
# 13    13       37.5      0.25     0.25     0.25   0.25              94.6
# 14    14       37.5      0.25     0.25     0.25   0.25              94.6
# 15    15       37.5      0.25     0.25     0.25   0.25              86.0
# 16    16       37.5      0.25     0.25     0.25   0.25              86.0
# 17    17       37.5      0.25     0.25     0.25   0.25              94.6
# 18    18       37.5      0.25     0.25     0.25   0.25              94.6
# 19    19       37.5      0.25     0.25     0.25   0.25              77.4
#
#     MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0               52.0                  71.9              62.0
# 1               52.0                  71.9              62.0
# 2               57.2                  79.0              68.2
# 3               57.2                  79.0              68.2
# 4               52.0                  71.9              62.0
# 5               52.0                  71.9              62.0
# 6               57.2                  79.0              68.2
# 7               57.2                  79.0              68.2
# 8               46.8                  64.7              55.8
# 9               46.8                  64.7              55.8
# 10              42.1                  58.2              50.2
# 11              52.0                  71.9              62.0
# 12              52.0                  71.9              62.0
# 13              57.2                  79.0              68.2
# 14              57.2                  79.0              68.2
# 15              52.0                  71.9              62.0
# 16              52.0                  71.9              62.0
# 17              57.2                  79.0              68.2
# 18              57.2                  79.0              68.2
# 19              46.8                  64.7              55.8
#
#     MinOfLowerTRange  AverageOfLowerTRange  RainingDays  AverageRainingDays  \
# 0               30.0                  50.8         16.0                0.26
# 1               30.0                  50.8          1.0                0.10
# 2               33.0                  55.9         16.0                0.26
# 3               33.0                  55.9          1.0                0.10
# 4               30.0                  50.8         24.0                0.39
# 5               30.0                  50.8         34.0                0.56
# 6               33.0                  55.9         24.0                0.39
# 7               33.0                  55.9         34.0                0.56
# 8               27.0                  45.8         16.0                0.26
# 9               27.0                  45.8          1.0                0.10
# 10              24.3                  41.2         16.0                0.26
# 11              30.0                  50.8         16.0                0.26
# 12              30.0                  50.8          1.0                0.10
# 13              33.0                  55.9         16.0                0.26
# 14              33.0                  55.9          1.0                0.10
# 15              30.0                  50.8         24.0                0.39
# 16              30.0                  50.8         34.0                0.56
# 17              33.0                  55.9         24.0                0.39
# 18              33.0                  55.9         34.0                0.56
# 19              27.0                  45.8         16.0                0.26
#
#     fruitset  fruitmass      seeds        yield
# 0   0.410652   0.408159  31.678898  3813.165795
# 1   0.444254   0.425458  33.449385  4947.605663
# 2   0.383787   0.399172  30.546306  3866.798965
# 3   0.407564   0.408789  31.562586  4303.943030
# 4   0.354413   0.382703  28.873714  3436.493543
# 5   0.309669   0.366284  27.345454  2825.003738
# 6   0.284443   0.352186  26.101179  2625.269164
# 7   0.246568   0.342826  25.042361  2379.905214
# 8   0.427977   0.414711  32.334153  4234.868585
# 9   0.464366   0.436346  34.849953  5356.871861
# 10  0.379906   0.375616  29.078356  4057.555205
# 11  0.398977   0.409269  31.597416  3941.255122
# 12  0.437375   0.426773  33.532675  4768.594369
# 13  0.364881   0.395636  30.124627  3720.711588
# 14  0.381314   0.402481  30.793741  3900.344042
# 15  0.350137   0.389381  29.550211  3387.785165
# 16  0.288159   0.359459  26.487322  2688.028831
# 17  0.279536   0.354415  26.282356  2508.375673
# 18  0.233554   0.335339  24.320627  1945.530615
# 19  0.426228   0.423988  33.299022  4310.625398

# %%
berry_data.shape
# Out:
# (777, 18)

# %%
berry_data.isna().sum()
# Out:
# Row#                    0
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %%
berry_data.describe()
# Out:
#              Row#   clonesize    honeybee     bumbles     andrena       osmia  \
# count  777.000000  777.000000  777.000000  777.000000  777.000000  777.000000
# mean   388.000000   18.767696    0.417133    0.282389    0.468817    0.562062
# std    224.444871    6.999063    0.978904    0.066343    0.161052    0.169119
# min      0.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    194.000000   12.500000    0.250000    0.250000    0.380000    0.500000
# 50%    388.000000   12.500000    0.250000    0.250000    0.500000    0.630000
# 75%    582.000000   25.000000    0.500000    0.380000    0.630000    0.750000
# max    776.000000   40.000000   18.430000    0.585000    0.750000    0.750000
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count        777.000000        777.000000            777.000000
# mean          82.277091         49.700515             68.723037
# std            9.193745          5.595769              7.676984
# min           69.700000         39.000000             58.200000
# 25%           77.400000         46.800000             64.700000
# 50%           86.000000         52.000000             71.900000
# 75%           89.000000         52.000000             71.900000
# max           94.600000         57.200000             79.000000
#
#        MaxOfLowerTRange  MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# count        777.000000        777.000000            777.000000   777.000000
# mean          59.309395         28.690219             48.613127    18.309292
# std            6.647760          3.209547              5.417072    12.124226
# min           50.200000         24.300000             41.200000     1.000000
# 25%           55.800000         27.000000             45.800000     3.770000
# 50%           62.000000         30.000000             50.800000    16.000000
# 75%           66.000000         30.000000             50.800000    24.000000
# max           68.200000         33.000000             55.900000    34.000000
#
#        AverageRainingDays    fruitset   fruitmass       seeds        yield
# count          777.000000  777.000000  777.000000  777.000000   777.000000
# mean             0.320000    0.502121    0.445983   36.122432  6012.849165
# std              0.171279    0.079445    0.040333    4.377889  1356.955318
# min              0.060000    0.192732    0.311921   22.079199  1637.704022
# 25%              0.100000    0.454725    0.416281   33.116091  5124.854901
# 50%              0.260000    0.508297    0.445587   36.166044  6107.382466
# 75%              0.390000    0.561297    0.476149   39.239668  7022.189731
# max              0.560000    0.652144    0.535660   46.585105  8969.401842

# %%
berry_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row#                  777 non-null    int64
#  1   clonesize             777 non-null    float64
#  2   honeybee              777 non-null    float64
#  3   bumbles               777 non-null    float64
#  4   andrena               777 non-null    float64
#  5   osmia                 777 non-null    float64
#  6   MaxOfUpperTRange      777 non-null    float64
#  7   MinOfUpperTRange      777 non-null    float64
#  8   AverageOfUpperTRange  777 non-null    float64
#  9   MaxOfLowerTRange      777 non-null    float64
#  10  MinOfLowerTRange      777 non-null    float64
#  11  AverageOfLowerTRange  777 non-null    float64
#  12  RainingDays           777 non-null    float64
#  13  AverageRainingDays    777 non-null    float64
#  14  fruitset              777 non-null    float64
#  15  fruitmass             777 non-null    float64
#  16  seeds                 777 non-null    float64
#  17  yield                 777 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 109.4 KB

# %%
berry_data.nunique()
# Out:
# Row#                    777
# clonesize                 6
# honeybee                  7
# bumbles                  10
# andrena                  12
# osmia                    12
# MaxOfUpperTRange          5
# MinOfUpperTRange          5
# AverageOfUpperTRange      5
# MaxOfLowerTRange          5
# MinOfLowerTRange          5
# AverageOfLowerTRange      5
# RainingDays               5
# AverageRainingDays        5
# fruitset                777
# fruitmass               777
# seeds                   777
# yield                   777
# dtype: int64

# %% [markdown]
# # Univariate Analysis
# <p style="font-size: 17px;"> We have no null values, and overall dtype of the dataset is <b>float</b> So the next step will be Preprocessing </p>

# %%
figs = plt.figure(figsize=(15,7))
plt.title("Blueberry Yield continuity curve")
ax1 = figs.add_subplot(121)
ax2 = figs.add_subplot(122)
x = berry_data["yield"]
plt.xlabel("Yield Value")
ax1.hist(x, bins=20, color="salmon")
ax2.boxplot(x);

# %%
unpivot = pd.melt(berry_data, berry_data.describe().columns[-1], berry_data.describe().columns[:-1])
unpivot
# Out:
#              yield variable      value
# 0      3813.165795     Row#   0.000000
# 1      4947.605663     Row#   1.000000
# 2      3866.798965     Row#   2.000000
# 3      4303.943030     Row#   3.000000
# 4      3436.493543     Row#   4.000000
# ...            ...      ...        ...
# 13204  5333.873335    seeds  33.447471
# 13205  3373.436842    seeds  28.462005
# 13206  4203.027624    seeds  30.748240
# 13207  4166.299735    seeds  30.582161
# 13208  3943.131681    seeds  29.742583
#
# [13209 rows x 3 columns]

# %%
unpivot = pd.melt(berry_data, berry_data.describe().columns[-1], berry_data.describe().columns[:-1])

g = sns.FacetGrid(unpivot, col="variable", col_wrap=3, sharex=False, sharey=False)
g.map(sns.kdeplot, "value")

plt.show()

# %%
unpivot = pd.melt(berry_data, berry_data.describe().columns[-1], berry_data.describe().columns[:-1])

g = sns.FacetGrid(unpivot, col="variable", col_wrap=3, sharex=False, sharey=False)
g.map(sns.boxplot, "value")

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(17,12))
sns.set()
sns.heatmap(berry_data.corr(), annot=True, cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preprocessing
#
#
# columns to drop: 'Row#', 'MaxOfUpperTRange', 'MinOfUpperTRange', 'MaxOfLowerTRange', 'MinOfLowerTRange', 'RainingDays', 'honeybee'

# %%
berry_data.columns
# Out:
# Index(['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
bbry_data_process = berry_data.drop(columns=['Row#', 'MaxOfUpperTRange', 'MinOfUpperTRange', 'MaxOfLowerTRange', 'MinOfLowerTRange', 'RainingDays', 'honeybee'])
bbry_data_process
# Out:
#      clonesize  bumbles  andrena  osmia  AverageOfUpperTRange  \
# 0         37.5    0.250    0.250  0.250                  71.9
# 1         37.5    0.250    0.250  0.250                  71.9
# 2         37.5    0.250    0.250  0.250                  79.0
# 3         37.5    0.250    0.250  0.250                  79.0
# 4         37.5    0.250    0.250  0.250                  71.9
# ..         ...      ...      ...    ...                   ...
# 772       10.0    0.117    0.409  0.058                  71.9
# 773       40.0    0.117    0.409  0.058                  71.9
# 774       20.0    0.117    0.409  0.058                  71.9
# 775       20.0    0.117    0.409  0.058                  65.6
# 776       20.0    0.117    0.409  0.058                  65.6
#
#      AverageOfLowerTRange  AverageRainingDays  fruitset  fruitmass      seeds  \
# 0                    50.8                0.26  0.410652   0.408159  31.678898
# 1                    50.8                0.10  0.444254   0.425458  33.449385
# 2                    55.9                0.26  0.383787   0.399172  30.546306
# 3                    55.9                0.10  0.407564   0.408789  31.562586
# 4                    50.8                0.39  0.354413   0.382703  28.873714
# ..                    ...                 ...       ...        ...        ...
# 772                  50.8                0.06  0.486815   0.428012  33.447471
# 773                  50.8                0.06  0.342841   0.377915  28.462005
# 774                  50.8                0.39  0.404617   0.401670  30.748240
# 775                  45.3                0.06  0.401538   0.399935  30.582161
# 776                  45.3                0.39  0.384646   0.392303  29.742583
#
#            yield
# 0    3813.165795
# 1    4947.605663
# 2    3866.798965
# 3    4303.943030
# 4    3436.493543
# ..           ...
# 772  5333.873335
# 773  3373.436842
# 774  4203.027624
# 775  4166.299735
# 776  3943.131681
#
# [777 rows x 11 columns]

# %%
part1 = bbry_data_process.drop(columns=['yield'])
part2 = bbry_data_process[['yield']]
part1
# Out:
#      clonesize  bumbles  andrena  osmia  AverageOfUpperTRange  \
# 0         37.5    0.250    0.250  0.250                  71.9
# 1         37.5    0.250    0.250  0.250                  71.9
# 2         37.5    0.250    0.250  0.250                  79.0
# 3         37.5    0.250    0.250  0.250                  79.0
# 4         37.5    0.250    0.250  0.250                  71.9
# ..         ...      ...      ...    ...                   ...
# 772       10.0    0.117    0.409  0.058                  71.9
# 773       40.0    0.117    0.409  0.058                  71.9
# 774       20.0    0.117    0.409  0.058                  71.9
# 775       20.0    0.117    0.409  0.058                  65.6
# 776       20.0    0.117    0.409  0.058                  65.6
#
#      AverageOfLowerTRange  AverageRainingDays  fruitset  fruitmass      seeds
# 0                    50.8                0.26  0.410652   0.408159  31.678898
# 1                    50.8                0.10  0.444254   0.425458  33.449385
# 2                    55.9                0.26  0.383787   0.399172  30.546306
# 3                    55.9                0.10  0.407564   0.408789  31.562586
# 4                    50.8                0.39  0.354413   0.382703  28.873714
# ..                    ...                 ...       ...        ...        ...
# 772                  50.8                0.06  0.486815   0.428012  33.447471
# 773                  50.8                0.06  0.342841   0.377915  28.462005
# 774                  50.8                0.39  0.404617   0.401670  30.748240
# 775                  45.3                0.06  0.401538   0.399935  30.582161
# 776                  45.3                0.39  0.384646   0.392303  29.742583
#
# [777 rows x 10 columns]

# %%
Q1 = part1.quantile(0.25)
Q3 = part1.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# clonesize               12.500000
# bumbles                  0.130000
# andrena                  0.250000
# osmia                    0.250000
# AverageOfUpperTRange     7.200000
# AverageOfLowerTRange     5.000000
# AverageRainingDays       0.290000
# fruitset                 0.106571
# fruitmass                0.059869
# seeds                    6.123577
# dtype: float64

# %%
bbry_data_iqr = bbry_data_process[~((bbry_data_process < (Q1 - 1.5 * IQR)) | (bbry_data_process > (Q3 + 1.5 * IQR))).any(axis=1)]
bbry_data_iqr.shape
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_15324/2322028197.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   bbry_data_iqr = bbry_data_process[~((bbry_data_process < (Q1 - 1.5 * IQR)) | (bbry_data_process > (Q3 + 1.5 * IQR))).any(axis=1)]
# (752, 11)

# %%
bbry_data_iqr
# Out:
#      clonesize  bumbles  andrena  osmia  AverageOfUpperTRange  \
# 0         37.5     0.25     0.25   0.25                  71.9
# 1         37.5     0.25     0.25   0.25                  71.9
# 2         37.5     0.25     0.25   0.25                  79.0
# 3         37.5     0.25     0.25   0.25                  79.0
# 4         37.5     0.25     0.25   0.25                  71.9
# ..         ...      ...      ...    ...                   ...
# 754       25.0     0.38     0.63   0.50                  64.7
# 755       25.0     0.38     0.63   0.50                  58.2
# 756       25.0     0.38     0.63   0.50                  58.2
# 757       25.0     0.38     0.63   0.50                  64.7
# 758       25.0     0.38     0.63   0.50                  64.7
#
#      AverageOfLowerTRange  AverageRainingDays  fruitset  fruitmass      seeds  \
# 0                    50.8                0.26  0.410652   0.408159  31.678898
# 1                    50.8                0.10  0.444254   0.425458  33.449385
# 2                    55.9                0.26  0.383787   0.399172  30.546306
# 3                    55.9                0.10  0.407564   0.408789  31.562586
# 4                    50.8                0.39  0.354413   0.382703  28.873714
# ..                    ...                 ...       ...        ...        ...
# 754                  45.8                0.10  0.558394   0.478666  39.448650
# 755                  41.2                0.26  0.494678   0.429703  34.784888
# 756                  41.2                0.10  0.502842   0.430369  35.185971
# 757                  45.8                0.39  0.513889   0.458966  37.209554
# 758                  45.8                0.56  0.496826   0.447096  35.756223
#
#            yield
# 0    3813.165795
# 1    4947.605663
# 2    3866.798965
# 3    4303.943030
# 4    3436.493543
# ..           ...
# 754  7184.013843
# 755  6292.960756
# 756  6374.444297
# 757  6180.951419
# 758  5700.243243
#
# [752 rows x 11 columns]

# %%
unpivot = pd.melt(bbry_data_iqr, bbry_data_iqr.describe().columns[-1], bbry_data_iqr.describe().columns[:-1])

g = sns.FacetGrid(unpivot, col="variable", col_wrap=3, sharex=False, sharey=False)
g.map(sns.boxplot, "value")

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
z = np.abs(stats.zscore(bbry_data_iqr))
print(z)
# Out:
#      clonesize   bumbles   andrena     osmia  AverageOfUpperTRange  \
# 0     2.749113  0.626572  1.435837  2.181039              0.430009
# 1     2.749113  0.626572  1.435837  2.181039              0.430009
# 2     2.749113  0.626572  1.435837  2.181039              1.348923
# 3     2.749113  0.626572  1.435837  2.181039              1.348923
# 4     2.749113  0.626572  1.435837  2.181039              0.430009
# ..         ...       ...       ...       ...                   ...
# 754   0.932476  1.595986  0.989132  0.510834              0.501847
# 755   0.932476  1.595986  0.989132  0.510834              1.343105
# 756   0.932476  1.595986  0.989132  0.510834              1.343105
# 757   0.932476  1.595986  0.989132  0.510834              0.501847
# 758   0.932476  1.595986  0.989132  0.510834              0.501847
#
#      AverageOfLowerTRange  AverageRainingDays  fruitset  fruitmass     seeds  \
# 0                0.419327            0.377097  1.277828   1.044250  1.128742
# 1                0.419327            1.326308  0.827835   0.592303  0.701814
# 2                1.354981            0.377097  1.637605   1.279035  1.401850
# 3                1.354981            1.326308  1.319181   1.027781  1.156789
# 4                0.419327            0.394137  2.030966   1.709321  1.805172
# ..                    ...                 ...       ...        ...       ...
# 754              0.497981            1.326308  0.700693   0.797839  0.744824
# 755              1.341904            0.377097  0.152580   0.481400  0.379776
# 756              1.341904            1.326308  0.043240   0.463995  0.283061
# 757              0.497981            0.394137  0.104695   0.283147  0.204898
# 758              0.497981            1.402674  0.123806   0.026988  0.145552
#
#         yield
# 0    1.747934
# 1    0.873141
# 2    1.706576
# 3    1.369484
# 4    2.038395
# ..        ...
# 754  0.851407
# 755  0.164295
# 756  0.227128
# 757  0.077922
# 758  0.292764
#
# [752 rows x 11 columns]

# %%
bbry_data_zscore = bbry_data_iqr[(z < 3).all(axis=1)]
bbry_data_zscore.shape
# Out:
# (752, 11)

# %%
unpivot = pd.melt(bbry_data_zscore, bbry_data_zscore.describe().columns[-1], bbry_data_zscore.describe().columns[:-1])

g = sns.FacetGrid(unpivot, col="variable", col_wrap=3, sharex=False, sharey=False)
g.map(sns.boxplot, "value")

plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
bbry_data_process = bbry_data_zscore
bbry_data_process
# Out:
#      clonesize  bumbles  andrena  osmia  AverageOfUpperTRange  \
# 0         37.5     0.25     0.25   0.25                  71.9
# 1         37.5     0.25     0.25   0.25                  71.9
# 2         37.5     0.25     0.25   0.25                  79.0
# 3         37.5     0.25     0.25   0.25                  79.0
# 4         37.5     0.25     0.25   0.25                  71.9
# ..         ...      ...      ...    ...                   ...
# 754       25.0     0.38     0.63   0.50                  64.7
# 755       25.0     0.38     0.63   0.50                  58.2
# 756       25.0     0.38     0.63   0.50                  58.2
# 757       25.0     0.38     0.63   0.50                  64.7
# 758       25.0     0.38     0.63   0.50                  64.7
#
#      AverageOfLowerTRange  AverageRainingDays  fruitset  fruitmass      seeds  \
# 0                    50.8                0.26  0.410652   0.408159  31.678898
# 1                    50.8                0.10  0.444254   0.425458  33.449385
# 2                    55.9                0.26  0.383787   0.399172  30.546306
# 3                    55.9                0.10  0.407564   0.408789  31.562586
# 4                    50.8                0.39  0.354413   0.382703  28.873714
# ..                    ...                 ...       ...        ...        ...
# 754                  45.8                0.10  0.558394   0.478666  39.448650
# 755                  41.2                0.26  0.494678   0.429703  34.784888
# 756                  41.2                0.10  0.502842   0.430369  35.185971
# 757                  45.8                0.39  0.513889   0.458966  37.209554
# 758                  45.8                0.56  0.496826   0.447096  35.756223
#
#            yield
# 0    3813.165795
# 1    4947.605663
# 2    3866.798965
# 3    4303.943030
# 4    3436.493543
# ..           ...
# 754  7184.013843
# 755  6292.960756
# 756  6374.444297
# 757  6180.951419
# 758  5700.243243
#
# [752 rows x 11 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### We will now train the model using both the splits of dataset, <br>and check the metrics of the same on
#
# * Linear Regression
# * Ridge Regularization
# * Lasso Regularization
# * Random Forest
# * Decision Tree
# * XGBoost

# %%
X = bbry_data_process.drop(["yield"], axis=1)
y = bbry_data_process['yield']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %% [markdown]
# ### LinearRegression

# %%
lreg = LinearRegression()

lreg.fit(X_train, y_train)

ypred = lreg.predict(X_test)

# %%
mae_linear = mean_absolute_error(y_test, ypred)
mse_linear = mean_squared_error(y_test, ypred)
rmse_linear = np.sqrt(mse_linear)
rsq_linear = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_linear)
print('MSE: %.3f' % mse_linear)
print('RMSE: %.3f' % rmse_linear)
print('R-Square: %.3f' % rsq_linear)
# Out:
# MAE: 96.280
# MSE: 16166.601
# RMSE: 127.148
# R-Square: 0.991

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge

# %% [markdown]
# # Ridge Regularization

# %%
#!pip install scikit-optimize

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV, cross_val_score
ridge = Ridge()
parameters = {'alpha': [1e-15,1e-10,1e-7,1e-5,1e-0,1e-3,1.5,10,50,100]}
ridge_regressor = GridSearchCV(ridge, parameters, scoring = 'neg_mean_squared_error',cv = 5)
ridge_regressor.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-07, 1e-05, 1.0, 0.001, 1.5,
#                                    10, 50, 100]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_score_)
print(ridge_regressor.best_params_)
# Out:
# -14151.86211748578
# {'alpha': 1e-05}

# %%
ypred = ridge_regressor.predict(X_test)

# %%
mae_ridge = mean_absolute_error(y_test, ypred)
mse_ridge = mean_squared_error(y_test, ypred)
rmse_ridge = np.sqrt(mse_ridge)
rsq_ridge = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_ridge)
print('MSE: %.3f' % mse_ridge)
print('RMSE: %.3f' % rmse_ridge)
print('R-Square: %.3f' % rsq_ridge)
# Out:
# MAE: 96.275
# MSE: 16165.262
# RMSE: 127.143
# R-Square: 0.991

# %% [markdown]
# # Lasso regularization

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
parameters= {'alpha': [1e-15,1e-10,1e-7,1e-5,1e-0,1e-3,1.5,10,50,100]}
lasso_regressor = GridSearchCV(lasso, parameters, scoring = 'neg_mean_squared_error',cv = 5)
lasso_regressor.fit(X_train, y_train)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+06, tolerance: 6.388e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.720e+06, tolerance: 6.694e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.716e+06, tolerance: 6.759e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+06, tolerance: 6.574e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+06, tolerance: 6.388e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.720e+06, tolerance: 6.694e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.716e+06, tolerance: 6.759e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+06, tolerance: 6.574e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+06, tolerance: 6.388e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.720e+06, tolerance: 6.694e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.716e+06, tolerance: 6.759e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+06, tolerance: 6.574e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.785e+06, tolerance: 6.388e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.720e+06, tolerance: 6.694e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.743e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.716e+06, tolerance: 6.759e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+06, tolerance: 6.574e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.763e+06, tolerance: 6.388e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.675e+06, tolerance: 6.694e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.727e+06, tolerance: 6.693e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.705e+06, tolerance: 6.759e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.583e+06, tolerance: 6.574e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.406e+06, tolerance: 8.281e+04
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-07, 1e-05, 1.0, 0.001, 1.5,
#                                    10, 50, 100]},
#              scoring='neg_mean_squared_error')

# %%
print(lasso_regressor.best_score_)
print(lasso_regressor.best_params_)
# Out:
# -14029.129775870664
# {'alpha': 1e-05}

# %%
ypred = ridge_regressor.predict(X_test)

# %%
mae_lasso = mean_absolute_error(y_test, ypred)
mse_lasso = mean_squared_error(y_test, ypred)
rmse_lasso = np.sqrt(mse_ridge)
rsq_lasso = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_lasso)
print('MSE: %.3f' % mse_lasso)
print('RMSE: %.3f' % rmse_lasso)
print('R-Square: %.3f' % rsq_lasso)
# Out:
# MAE: 96.275
# MSE: 16165.262
# RMSE: 127.143
# R-Square: 0.991

# %% [markdown]
# ### RandomForest Regression

# %%
rf = RandomForestRegressor()

rf.fit(X_train, y_train)
    
ypred = rf.predict(X_test)

# %%
mae_rf = mean_absolute_error(y_test, ypred)
mse_rf = mean_squared_error(y_test, ypred)
rmse_rf = np.sqrt(mse_rf)
rsq_rf = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_rf)
print('MSE: %.3f' % mse_rf)
print('RMSE: %.3f' % rmse_rf)
print('R-Square: %.3f' % rsq_rf)
# Out:
# MAE: 118.089
# MSE: 22107.076
# RMSE: 148.684
# R-Square: 0.987

# %% [markdown]
# ### Decision Tree Regression

# %%
dtree = DecisionTreeRegressor()

dtree.fit(X_train, y_train)

yhat = dtree.predict(X_test)

# %%
mae_dt = mean_absolute_error(y_test, ypred)
mse_dt = mean_squared_error(y_test, ypred)
rmse_dt = np.sqrt(mse_dt)
rsq_dt = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_dt)
print('MSE: %.3f' % mse_dt)
print('RMSE: %.3f' % rmse_dt)
print('R-Square: %.3f' % rsq_dt)
# Out:
# MAE: 118.089
# MSE: 22107.076
# RMSE: 148.684
# R-Square: 0.987

# %% [markdown]
# ### XGBRegression

# %%
xgb = XGBRegressor()

xgb.fit(X_train, y_train)

ypred = xgb.predict(X_test)

# %%
mae_xgb = mean_absolute_error(y_test, ypred)
mse_xgb = mean_squared_error(y_test, ypred)
rmse_xgb = np.sqrt(mse_dt)
rsq_xgb = r2_score(y_test, ypred)

print('MAE: %.3f' % mae_xgb)
print('MSE: %.3f' % mse_xgb)
print('RMSE: %.3f' % rmse_xgb)
print('R-Square: %.3f' % rsq_xgb)
# Out:
# MAE: 114.239
# MSE: 22641.945
# RMSE: 148.684
# R-Square: 0.987

# %% [markdown]
# # Model Evaluation
#
#
# <p style="font-size: 17px;"> We can also check the R<sup>2</sup> score. Here, we will be aiming to reduce the <br><b>RMSE</b> and <b> MAE </b> values</p>
#
# The comparative BarPlot shows the values of each. We have **Linear Regression** (150.309) and **XGBoost** (145.976) at the lowest Error Rate

# %%
# CV evaluation for all the models
# from sklearn.metrics import r2_score

# %%
error_rec = {
    "linearreg": {
        "mae": mae_linear,
        "rmse": rmse_linear,
        'r2': rsq_linear*100
    },
    "ridge_reg": {
        "mae": mae_xgb,
        "rmse": rmse_xgb,
        'r2': rsq_xgb*100
    },
    "lasso_reg": {
        "mae": mae_xgb,
        "rmse": rmse_xgb,
        'r2': rsq_xgb*100
    },
    "randomforest": {
        "mae": mae_rf,
        "rmse": rmse_rf,
        'r2': rsq_rf*100
    },
    "decisiontree": {
        "mae": mae_dt,
        "rmse": rmse_dt,
        'r2': rsq_dt*100
    },
    "xgboost": {
        "mae": mae_xgb,
        "rmse": rmse_xgb,
        'r2': rsq_xgb*100
    },
    
}

pd.DataFrame(error_rec).plot(kind="bar", 
             color=[
                 sns.color_palette("pastel")[0], 
                 sns.color_palette("pastel")[1], 
                 sns.color_palette("pastel")[2], 
                 sns.color_palette("pastel")[3],
                 sns.color_palette("pastel")[4],
                 sns.color_palette("pastel")[5]]);

# %% [markdown]
# # After Regularizing Score comes as 0.98 which tells that model is performing well on the data

# %% [markdown]
# # Linear regression is giving best results
